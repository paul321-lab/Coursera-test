# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b> Paul Ngobi Bagiire <br> Data Analyst </b>

# %% [markdown]
# I am interested in data science because data has been the secret fuel for many successful entreprises in the world so far.

# %% [markdown]
# <h3>The code below is to create a plot of numbers in an array</h3>

# %%
import numpy as np
import matplotlib.pyplot as plt
 
x = np.array(range(0, 10))
y = np.array([100, 23, 44, 12, 55, 85, 69, 33, 75, 2])
plt.title("Plotting 1-D array")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x, y, color = "red", marker = "o", label = "Array elements")
plt.legend()
plt.show()

# %% [markdown]
# <h5>bulleted lsit</h5>
# <li>shorts</li>
# <li>trousers</li>
# <li>shirts</li>
# <li>shoes</li>
# <li>socks</li>

# %% [markdown]
# <h5>numbered list</h5>
# <ol start="1">
#   <li>shoes</li>
#   <li>shirts</li>
#   <li>trousers</li>
#   <li>socks</li>
# </ol>

# %% [markdown]
# <h5>Tables</h5>
# <table ><tr><th >Stretch/Untouched <th><th> ProbDistribution <th><th> Accuracy <tr><tr>
# <tr><td> Stretched <td><td> Gaussian <td><td> .843 <td><tr><table>
